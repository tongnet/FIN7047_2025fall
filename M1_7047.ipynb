# %%
#pip install openai
from openai import OpenAI

# Initialize client
client = OpenAI(api_key="Enter API key")

def generate_paris_itinerary(days=3, budget_per_day=250):
    prompt = f"""
    Generate a detailed {days}-day travel itinerary for Paris with daily activities and an estimated budget. 
    The budget per day is €{budget_per_day}. Include attractions, dining suggestions, and a breakdown of costs.
    """

    # New API call style
    response = client.chat.completions.create(
        model="gpt-4o-mini",   # or "gpt-4o", "gpt-4.1" depending on your plan
        messages=[
            {"role": "system", "content": "You are a helpful travel assistant."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=1000,
        temperature=0.7
    )

    return response.choices[0].message.content.strip()

# Generate and print itinerary
itinerary = generate_paris_itinerary(days=3, budget_per_day=250)
print(itinerary)
# Out:
# ### 3-Day Travel Itinerary for Paris
#
# #### Day 1: Classic Paris
#
# **Morning:**
# - **Breakfast at Café de Flore** (Approx. €15)
#   - Enjoy a classic Parisian breakfast of croissants, coffee, and fresh juice.
# - **Visit the Eiffel Tower** (Ticket: €26)
#   - Arrive early to avoid long lines and enjoy stunning views from the top.
#
# **Afternoon:**
# - **Lunch at Le Relais de l’Entrecôte** (Approx. €25)
#   - Famous for its steak-frites; no need to look at the menu, just order!
# - **Explore the Champs-Élysées** (Free)
#   - Stroll down this iconic avenue, window shopping and taking in the sights.
# - **Visit the Arc de Triomphe** (Ticket: €13)
#   - Climb to the top for panoramic views of Paris.
#
# **Evening:**
# - **Dinner at Le Petit Cler** (Approx. €30)
#   - A charming bistro near the Eiffel Tower with traditional French dishes.
# - **Seine River Cruise** (Approx. €15)
#   - End your day with a relaxing cruise to see the city illuminated at night.
#
# **Daily Total: €250**
# - Breakfast: €15
# - Eiffel Tower: €26
# - Lunch: €25
# - Arc de Triomphe: €13
# - Dinner: €30
# - Seine River Cruise: €15
# - **Total: €124** (remaining €126 for souvenirs, snacks, etc.)
#
# ---
#
# #### Day 2: Art and Culture
#
# **Morning:**
# - **Breakfast at Angelina** (Approx. €20)
#   - Famous for its hot chocolate and pastries.
# - **Visit the Louvre Museum** (Ticket: €17)
#   - Home to thousands of art pieces, including the Mona Lisa. Spend a few hours here.
#
# **Afternoon:**
# - **Lunch at Café Marly** (Approx. €30)
#   - Located within the Louvre, offering a great view of the pyramid.
# - **Visit Musée d'Orsay** (Ticket: €16)
#   - Explore the stunning collection of Impressionist and Post-Impressionist masterpieces.
#
# **Evening:**
# - **Dinner at Le Comptoir de la Gastronomie** (Approx. €25)
#   - Enjoy gourmet French food and a casual dining atmosphere.
# - **Evening Stroll in Montmartre** (Free)
#   - Explore the charming streets and visit Sacré-Cœur Basilica for a beautiful sunset view.
#
# **Daily Total: €250**
# - Breakfast: €20
# - Louvre: €17
# - Lunch: €30
# - Musée d'Orsay: €16
# - Dinner: €25
# - **Total: €108** (remaining €142 for souvenirs, snacks, etc.)
#
# ---
#
# #### Day 3: Neighborhoods and Local Experiences
#
# **Morning:**
# - **Breakfast at a local boulangerie** (Approx. €10)
#   - Pick up fresh pastries and coffee.
# - **Visit the Latin Quarter** (Free)
#   - Explore the vibrant streets and visit the Panthéon (Ticket: €11).
#
# **Afternoon:**
# - **Lunch at Le Procope** (Approx. €35)
#   - The oldest café in Paris, enjoy traditional French cuisine.
# - **Explore Luxembourg Gardens** (Free)
#   - Relax in the beautiful gardens and enjoy the scenery.
#
# **Evening:**
# - **Dinner at Chez Janou** (Approx. €30)
#   - A lovely Provencal restaurant known for its ambiance and dishes.
# - **Visit a Cabaret Show at Moulin Rouge** (Ticket: €100)
#   - Experience the iconic Parisian cabaret with an unforgettable performance.
#
# **Daily Total: €250**
# - Breakfast: €10
# - Panthéon: €11
# - Lunch: €35
# - Dinner: €30
# - Moulin Rouge: €100
# - **Total: €186** (remaining €64 for souvenirs, snacks, etc.)
#
# ---
#
# ### Summary of Estimated Costs
# - **Day 1 Total:** €124
# - **Day 2 Total:** €108
# - **Day 3 Total:** €186
# - **Overall Total for 3 Days:** €418
# - **Total Budget:** €750 (for 3 days at €250/day)
# - **Remaining Budget for Extras:** €332 for souvenirs, snacks, and any additional activities.
#
# This itinerary provides a balanced mix of iconic sights, dining experiences, and local culture, all within your budget. Enjoy your trip to Paris!

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch, Rectangle

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Draw the boxes and circles in three columns
ax.text(0.2, 0.9, 'Bank', fontsize=14, ha='center', va='center', bbox=dict(facecolor='white', edgecolor='black'))
ax.text(0.5, 0.9, 'Insurer', fontsize=14, ha='center', va='center', bbox=dict(facecolor='white', edgecolor='black'))
ax.text(0.8, 0.9, 'Asset\nManager', fontsize=14, ha='center', va='center', bbox=dict(facecolor='white', edgecolor='black'))

# Draw the customer circles in three columns
ax.text(0.2, 0.5, 'Customer', fontsize=12, ha='center', va='center', bbox=dict(facecolor='white', edgecolor='black'))
ax.text(0.5, 0.5, 'Customer', fontsize=12, ha='center', va='center', bbox=dict(facecolor='white', edgecolor='black'))
ax.text(0.8, 0.5, 'Customer', fontsize=12, ha='center', va='center', bbox=dict(facecolor='white', edgecolor='black'))

# Draw the arrows (top to bottom to represent the transactions)
arrowprops = dict(facecolor='black', arrowstyle='-|>', lw=1.5, mutation_scale=20)

# Bank to Customer (left column, two arrows)
ax.add_patch(FancyArrowPatch((0.15, 0.83), (0.15, 0.53), **arrowprops))
ax.add_patch(FancyArrowPatch((0.25, 0.53), (0.25, 0.83), **arrowprops))
ax.text(0.14, 0.7, 'Loan', fontsize=10, ha='right', va='center')
ax.text(0.26, 0.7, 'Interest', fontsize=10, ha='left', va='center')

# Insurer to Customer (middle column, two arrows)
ax.add_patch(FancyArrowPatch((0.45, 0.83), (0.45, 0.53), **arrowprops))
ax.add_patch(FancyArrowPatch((0.55, 0.53), (0.55, 0.83), **arrowprops))
ax.text(0.44, 0.7, 'Policy', fontsize=10, ha='right', va='center')
ax.text(0.56, 0.7, 'Premium', fontsize=10, ha='left', va='center')

# Asset Manager to Customer (right column)
ax.add_patch(FancyArrowPatch((0.75, 0.83), (0.75, 0.53), **arrowprops))
ax.add_patch(FancyArrowPatch((0.85, 0.53), (0.85, 0.83), **arrowprops))
ax.text(0.74, 0.7, 'Investment', fontsize=10, ha='right', va='center')
ax.text(0.89, 0.7, 'Fee', fontsize=10, ha='right', va='center')

# Set limits and remove axes
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')

# Show the plot
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
